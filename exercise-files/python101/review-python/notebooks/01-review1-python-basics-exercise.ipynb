# %% [markdown]
# ## This notebook runs through a few simple python things...
#
# - Different kinds of data types
#     - Working with Numbers
#     - Working with Strings
# - Storing Values in Variables
# - Storing Multiple Values in Lists
# - Functions
# - Creating Your Own Functions

# %% [markdown]
# ## Different kinds of data types
#
# #### Working with Numbers
# Python can handle three types of information/data: floats (numbers with decimals, e.g. 3.14), integers (1,2,3,4,etc.) and strings.
#
# Let’s first talk about how Python can read numbers!

# %%
4 + 4
# Out:
# 8

# %%
48529 * 238429
# Out:
# 11570720941

# %% [markdown]
# #### Working with Strings
# Strings are characters (everything from letters, numbers, characters and spaces) between inverted commas or quotation marks

# %%
"4"
# Out:
# '4'

# %% [markdown]
# You can concatenate strings by using the plus sign!

# %%
"cat" + " " + "dog"
# Out:
# 'cat dog'

# %% [markdown]
# Someone tell me what happens when you do this:

# %%
"4" + "4"
# Out:
# '44'

# %% [markdown]
# ## Variables
#
# Variables are really important in programming. They function kind of like boxes for your data: you can store a piece of data or many data points in a variable.
#  They can be any of the following:
#
# -   **Numbers**
# -   **Strings**, that are made up of letter, words, sentences, etc.
# -   **Placeholders**, that receive their value from inputs, computations or concatenation of other variables.
# -   **Lists**, that holds a multiple values in one variable.
# -   **Dictionaries**, variables that hold interrelated data or info as key-value pairs)
# -   **Functions**, bits of code that you can reuse...(more on this at some point this semester!).
#
# ...and many many other types of data.
#
#
# #### Storing Values in Variables
# Here’s how you create or declare a variable and store data (in this case a string) in it:

# %%
name = "Miguel"

# %%
print(name)
# Out:
# Miguel

# %% [markdown]
# And what’s great is that we can change what we store in it. Try this and let me know what happens:

# %% [markdown]
# #### Using f-string literals
# ```print(f"Some identifier words: {actual_variable}")```

# %%
print(f"My name is {name}")
# Out:
# My name is Miguel

# %% [markdown]
# #### Storing Multiple Values in Lists
# Alright, now you know how to store one data point in a variable, but who just wants one data point?! This is where lists can come in handy! A list is denoted through brackets and can contain various kinds of data points:

# %%
names = ["Ashley", "Emma", "Benjy", "Macy"]

# %%
print(names)
# Out:
# ['Ashley', 'Emma', 'Benjy', 'Macy']

# %%
names.append("Sohini")

# %%
print(names)
# Out:
# ['Ashley', 'Emma', 'Benjy', 'Macy', 'Sohini']

# %% [markdown]
# When you have a list, each item has a position which you can access through what is called its index:

# %%
print(names[2])
# Out:
# Benjy

# %% [markdown]
# What happens if you do `print(names[10])`?

# %%
for name in names:
    print(name)
# Out:
# Ashley
# Emma
# Benjy
# Macy
# Sohini

# %% [markdown]
# # Functions
#
# Functions are like a set of instructions that can be executed over and over again, like a recipe. The things you put inside the parentheses are called arguments  and are things that the function uses and modifies.
#
# In simplest terms (good for now), a ```built-in function``` comes as standard part of Python and carries out one or more steps on something we aim it at. What we target for the function goes inside the parenthesis:
#
# We use ```print(animals)``` to print the `animals` list or ```type(mixed_list)``` to see what datatype a variable contains.
#
# I will introduce others through the course as need. There are <a href="https://docs.python.org/3/library/functions.html">dozens of built-in functions</a>, but I will be introducing the most useful ones little by little.

# %%
def print_names(names):
    for name in names:
        print(name)

# %%
print_names(names)
# Out:
# Ashley
# Emma
# Benjy
# Macy
# Sohini

# %% [markdown]
# Another one is len(). What do you think it does? Try it out:

# %%
print(len(names[3]))
# Out:
# 4

# %% [markdown]
# #### Creating Your Own Functions
# Then you can also make functions!
#
# You declare a function by using the word `def`, by writing up a name for your function `writesentence()` and by parsing `word`:

# %% [markdown]
# This is how you’d run this function:

# %%
# goal = ["https://www.uber.com/global/en/r/united-states/arizona/cities/", "https://www.uber.com/global/en/r/united-states/alaska/cities/"]

# %%
state_names = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "District of Columbia", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]

# %%
urls = []
# The Python str.find() method locates the first occurrence of a substring within a string.

for state in state_names:
    state = state.replace(" ","-")
    state = state.lower()
    url = "https://www.uber.com/global/en/r/united-states/" + state + "/cities/"
    urls.append(url)

print(url)
# Out:
# beginning loop!!!
# https://www.uber.com/global/en/r/united-states/wyoming/cities/

# %%
print(urls)
# Out:
# ['https://www.uber.com/global/en/r/united-states/alabama/cities/', 'https://www.uber.com/global/en/r/united-states/alaska/cities/', 'https://www.uber.com/global/en/r/united-states/arizona/cities/', 'https://www.uber.com/global/en/r/united-states/arkansas/cities/', 'https://www.uber.com/global/en/r/united-states/california/cities/', 'https://www.uber.com/global/en/r/united-states/colorado/cities/', 'https://www.uber.com/global/en/r/united-states/connecticut/cities/', 'https://www.uber.com/global/en/r/united-states/delaware/cities/', 'https://www.uber.com/global/en/r/united-states/district-of-columbia/cities/', 'https://www.uber.com/global/en/r/united-states/florida/cities/', 'https://www.uber.com/global/en/r/united-states/georgia/cities/', 'https://www.uber.com/global/en/r/united-states/hawaii/cities/', 'https://www.uber.com/global/en/r/united-states/idaho/cities/', 'https://www.uber.com/global/en/r/united-states/illinois/cities/', 'https://www.uber.com/global/en/r/united-states/indiana/cities/', 'https://www.uber.com/global/en/r/united-states/iowa/cities/', 'https://www.uber.com/global/en/r/united-states/kansas/cities/', 'https://www.uber.com/global/en/r/united-states/kentucky/cities/', 'https://www.uber.com/global/en/r/united-states/louisiana/cities/', 'https://www.uber.com/global/en/r/united-states/maine/cities/', 'https://www.uber.com/global/en/r/united-states/maryland/cities/', 'https://www.uber.com/global/en/r/united-states/massachusetts/cities/', 'https://www.uber.com/global/en/r/united-states/michigan/cities/', 'https://www.uber.com/global/en/r/united-states/minnesota/cities/', 'https://www.uber.com/global/en/r/united-states/mississippi/cities/', 'https://www.uber.com/global/en/r/united-states/missouri/cities/', 'https://www.uber.com/global/en/r/united-states/montana/cities/', 'https://www.uber.com/global/en/r/united-states/nebraska/cities/', 'https://www.uber.com/global/en/r/united-states/nevada/cities/', 'https://www.uber.com/global/en/r/united-states/new-hampshire/cities/', 'https://www.uber.com/global/en/r/united-states/new-jersey/cities/', 'https://www.uber.com/global/en/r/united-states/new-mexico/cities/', 'https://www.uber.com/global/en/r/united-states/new-york/cities/', 'https://www.uber.com/global/en/r/united-states/north-carolina/cities/', 'https://www.uber.com/global/en/r/united-states/north-dakota/cities/', 'https://www.uber.com/global/en/r/united-states/ohio/cities/', 'https://www.uber.com/global/en/r/united-states/oklahoma/cities/', 'https://www.uber.com/global/en/r/united-states/oregon/cities/', 'https://www.uber.com/global/en/r/united-states/pennsylvania/cities/', 'https://www.uber.com/global/en/r/united-states/puerto-rico/cities/', 'https://www.uber.com/global/en/r/united-states/rhode-island/cities/', 'https://www.uber.com/global/en/r/united-states/south-carolina/cities/', 'https://www.uber.com/global/en/r/united-states/south-dakota/cities/', 'https://www.uber.com/global/en/r/united-states/tennessee/cities/', 'https://www.uber.com/global/en/r/united-states/texas/cities/', 'https://www.uber.com/global/en/r/united-states/utah/cities/', 'https://www.uber.com/global/en/r/united-states/vermont/cities/', 'https://www.uber.com/global/en/r/united-states/virginia/cities/', 'https://www.uber.com/global/en/r/united-states/washington/cities/', 'https://www.uber.com/global/en/r/united-states/west-virginia/cities/', 'https://www.uber.com/global/en/r/united-states/wisconsin/cities/', 'https://www.uber.com/global/en/r/united-states/wyoming/cities/']

# %%
hello = "heldfajldksfjalkdsjfl;akdsjf;asdjkf;lkadjlo"

# %%
# uber_dictionaries = [ {"state_name":"alabama", "uber_availability":"available", "uber_url":"https://www.uber.com/global/en/r/united-states/alabama/cities/"}, {"state_name":"alaska", "uber_availability":"not available", "uber_url":"https://www.uber.com/global/en/r/united-states/alaska/cities/"} ]

uber_dictionaries = []

for state in state_names:
    state = state.replace(" ","-")
    url = "https://www.uber.com/global/en/r/united-states/" + state + "/cities/"
    dictionary = {"state_name": state, "uber_availability": "available", "uber_url": url}
    uber_dictionaries.append(dictionary)


print(uber_dictionaries)
# Out:
# [{'state_name': 'Alabama', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Alabama/cities/'}, {'state_name': 'Alaska', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Alaska/cities/'}, {'state_name': 'Arizona', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Arizona/cities/'}, {'state_name': 'Arkansas', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Arkansas/cities/'}, {'state_name': 'California', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/California/cities/'}, {'state_name': 'Colorado', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Colorado/cities/'}, {'state_name': 'Connecticut', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Connecticut/cities/'}, {'state_name': 'Delaware', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Delaware/cities/'}, {'state_name': 'District-of-Columbia', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/District-of-Columbia/cities/'}, {'state_name': 'Florida', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Florida/cities/'}, {'state_name': 'Georgia', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Georgia/cities/'}, {'state_name': 'Hawaii', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Hawaii/cities/'}, {'state_name': 'Idaho', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Idaho/cities/'}, {'state_name': 'Illinois', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Illinois/cities/'}, {'state_name': 'Indiana', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Indiana/cities/'}, {'state_name': 'Iowa', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Iowa/cities/'}, {'state_name': 'Kansas', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Kansas/cities/'}, {'state_name': 'Kentucky', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Kentucky/cities/'}, {'state_name': 'Louisiana', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Louisiana/cities/'}, {'state_name': 'Maine', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Maine/cities/'}, {'state_name': 'Maryland', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Maryland/cities/'}, {'state_name': 'Massachusetts', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Massachusetts/cities/'}, {'state_name': 'Michigan', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Michigan/cities/'}, {'state_name': 'Minnesota', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Minnesota/cities/'}, {'state_name': 'Mississippi', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Mississippi/cities/'}, {'state_name': 'Missouri', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Missouri/cities/'}, {'state_name': 'Montana', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Montana/cities/'}, {'state_name': 'Nebraska', 'uber_availability': 'available', 'uber_url': 'https://www.uber.com/global/en/r/united-states/Nebraska/cities/'}, {'state_name': 'Nevada', 'uber_availabili ...

# %%
with open("../data/article.txt", "r") as file:
    data = file.read()
    print(data)
# Out:
# Lost Donkey Seen Living With Elk Herd 5 Years Later: 'Living His Best Life'
#
# Diesel the donkey, who disappeared in 2019, appears to be thriving with some new companions in the California wild.
#
# By
# Hilary Hanson
# Jun 15, 2024, 01:23 PM EDT
#
#
# A donkey who went missing five years ago in California has been caught on camera roaming with a herd of wild elk.
#
# “I bumped into a herd of elk that have adopted a donkey,” triathlete and hunter Max Fennell wrote on Instagram alongside a video of the blended herd. “I can’t get over seeing it and I’m amazed that the donkey looks happy and healthy!”
#
# The footage, recorded on a hunting trip and posted in March, shows a donkey standing among about a dozen elk. Members of the herd look at the camera simultaneously before trotting away.
#
# The storybook scene took place a few miles from the spot in Northern California’s Cache Creek Wilderness where a male donkey named Diesel disappeared in 2019, CBS Sacramento reported.
#
# One of Diesel’s owners, Terrie Drewry, told the news outlet in an interview published Thursday that the donkey in the video is definitely him.
#
# Diesel had been hiking with Terrie Drewry’s husband, Dave Drewry, when something spooked him and he got away. For weeks, the couple searched on foot and even with drone assistance to find the donkey, but were never able to locate him.
#
# It was “amazing” to see Diesel apparently thriving in the recent video, Terrie Drewry told CBS Sacramento.
#
# “He’s living his best life,” she said. “He’s happy. He’s healthy, and it was just a relief.”
#
# An earlier video, shared on Instagram by user Mikki Rhodes, also appeared to show Diesel wandering with elk. Rhodes said in a caption that his owners were “very happy” to see the donkey doing well.
#
# Diesel knows how to live without the aid of humans. He was originally a wild donkey, adopted through a Bureau of Land Management program. The program allows members of the public to adopt animals captured in the federal agency’s controversial roundups of wild horses and donkeys, aimed at reducing the free-roaming population of the animals on public lands.

# %%
with open("../data/page.html", "r") as file:
    data = file.read()
    print(data)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Unordered HTML List</h2>
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
#
# </body>
# </html>

# %%
import csv
import json

# %%
with open("../data/test.txt", "w+") as file:
    file.write("Hello? Is anybody there?")

# %%
# make a new csv into which we will write some data!
with open("../output/test.csv", "w+") as file:
    writer = csv.writer(file)
    writer.writerow(["pet", "name", "age"])

    data = [
        {"pet":"cat", "name":"fish", "age":3},
        {"pet":"walrus", "name":"sir", "age":5},
        {"pet":"turtle", "name":"fred", "age":105},
        {"pet":"dog", "name":"doggo", "age":2},
        {"pet":"cat", "name":"dragon", "age":3},
        {"pet":"cat", "name":"fish", "age":3},
        {"pet":"cat", "name":"sir", "age":5},
        {"pet":"turtle", "name":"fred", "age":105},
        {"pet":"dog", "name":"doggo", "age":2},
        {"pet":"cat", "name":"dragon", "age":3},
        {"pet":"cat", "name":"fish", "age":3},
        {"pet":"iguana", "name":"patrick", "age":2.5},
        {"pet":"turtle", "name":"fred", "age":105},
        {"pet":"dog", "name":"doggo", "age":2},
        {"pet":"cat", "name":"dragon", "age":3},
        {"pet":"hampster", "name":"hammy", "age":6},
        {"pet":"walrus", "name":"sir", "age":5},
        {"pet":"turtle", "name":"fred", "age":105},
        {"pet":"rat", "name":"kingrat", "age":1},
        {"pet":"monkey", "name":"monkey", "age":4}
    ]

    for pet in data:
        print(pet)
        writer.writerow([ pet["pet"], pet["name"], pet["age"] ])
# Out:
# {'pet': 'cat', 'name': 'fish', 'age': 3}
# {'pet': 'walrus', 'name': 'sir', 'age': 5}
# {'pet': 'turtle', 'name': 'fred', 'age': 105}
# {'pet': 'dog', 'name': 'doggo', 'age': 2}
# {'pet': 'cat', 'name': 'dragon', 'age': 3}
# {'pet': 'cat', 'name': 'fish', 'age': 3}
# {'pet': 'cat', 'name': 'sir', 'age': 5}
# {'pet': 'turtle', 'name': 'fred', 'age': 105}
# {'pet': 'dog', 'name': 'doggo', 'age': 2}
# {'pet': 'cat', 'name': 'dragon', 'age': 3}
# {'pet': 'cat', 'name': 'fish', 'age': 3}
# {'pet': 'iguana', 'name': 'patrick', 'age': 2.5}
# {'pet': 'turtle', 'name': 'fred', 'age': 105}
# {'pet': 'dog', 'name': 'doggo', 'age': 2}
# {'pet': 'cat', 'name': 'dragon', 'age': 3}
# {'pet': 'hampster', 'name': 'hammy', 'age': 6}
# {'pet': 'walrus', 'name': 'sir', 'age': 5}
# {'pet': 'turtle', 'name': 'fred', 'age': 105}
# {'pet': 'rat', 'name': 'kingrat', 'age': 1}
# {'pet': 'monkey', 'name': 'monkey', 'age': 4}

# %%
d = {"x":1}
d
# Out:
# {'x': 1}

# %%
d["x"]
# Out:
# 1
